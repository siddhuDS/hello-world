# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('D:\\Download_from_Chrome\\automobile-dataset\\Automobile_data.csv')
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
data.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
data['normalized-losses'].loc[data['normalized-losses']=='?'].value_counts()
# Out:
# ?    41
# Name: normalized-losses, dtype: int64

# %%
def clean(col_name):
    m = data[(data[col_name]!='?')][col_name].astype(float).mean()
    data[col_name] = data[col_name].str.replace('?',str(m)).astype(float)
    return data

# %%
clean('normalized-losses')
clean('bore')
clean('stroke')
clean('horsepower')
clean('peak-rpm')
clean('price')
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
def clean_categorical(column):
    mode = data[data[column]!='?'][column].astype(str).mode()
    data[column] = data[column].str.replace("?",str(mode)).astype(str)
    return data

# %%
clean_categorical('num-of-doors')
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
import matplotlib.pyplot as plt

# %%
data['make'].value_counts().nlargest(10).plot(kind='bar',figsize=(15,5))
plt.xlabel('Mke')
plt.ylabel('Number-of-vehicles')
plt.title('Numer-of-Vehicles (make)')
# Out:
# Text(0.5, 1.0, 'Numer-of-Vehicles (make)')

# %%
data.symboling.hist(bins=6,color='green')
plt.xlabel('Risk rating')
plt.ylabel('Number of vehicles')
plt.title("Insurance risk ratings of vehicles")
# Out:
# Text(0.5, 1.0, 'Insurance risk ratings of vehicles')

# %%
data['normalized-losses'].hist(bins=5,color='orange');
plt.xlabel('Normalized losses');
plt.ylabel('Number of vehicles')
plt.title("Normalized losses of vehicles")
# Out:
# Text(0.5, 1.0, 'Normalized losses of vehicles')

# %%
data['fuel-type'].value_counts().plot(kind='bar',color='purple')
plt.xlabel('Fuel type');
plt.ylabel('Number of vehicles')
plt.title("Fuel type frequence diagram")
# Out:
# Text(0.5, 1.0, 'Fuel type frequence diagram')

# %%
data['drive-wheels'].value_counts().plot(kind='bar',color='grey')
plt.xlabel('Drive wheels')
plt.ylabel('Number of vehicles')
plt.title("Drive wheels diagram")
# Out:
# Text(0.5, 1.0, 'Drive wheels diagram')

# %%
data['num-of-doors'].value_counts().plot(kind='bar',color='purple')
plt.title("Number of doors frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Number of doors')
# Out:
# Text(0.5, 0, 'Number of doors')

# %%
import seaborn as sns

# %%
g = sns.lmplot('price',"engine-size", data)
# Out:
# E:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
 g = sns.lmplot('normalized-losses',"symboling", data)

# %%
plt.scatter(data['engine-size'],data['peak-rpm'])
plt.xlabel('Engine size')
plt.ylabel('Peak RPM')
# Out:
# Text(0, 0.5, 'Peak RPM')

# %%
corr = data.corr()
plt.figure(figsize=(15,7))
a = sns.heatmap(corr, annot=True)
